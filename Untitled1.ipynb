# %%
x=2
print(x)
# Out:
# 2

# %%
x=1  
print(x)
x='hello'
print(x)
x=[1,2,3]
print(x)
# Out:
# 1
# hello
# [1, 2, 3]

# %%
 y=x
print(y)
# Out:
# [1, 2, 3]

# %%
x.append(4)
print(y)
# Out:
# [1, 2, 3, 4]

# %%
x="something else"
print(y)
# Out:
# [1, 2, 3, 4]

# %%
x=4
type(x)
# Out:
# int

# %%
x="hello"
type(x)
# Out:
# str

# %%
x=3.14159
type(x)
# Out:
# float
